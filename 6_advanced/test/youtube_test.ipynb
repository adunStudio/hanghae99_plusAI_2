# %%
# !pip install yt_dlp
# Out:
# Requirement already satisfied: yt_dlp in /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages (2025.1.15)

# %%
import pandas as pd

video_parse_list = pd.read_csv('./videos_parse_list.csv')
video_parse_list.head()
# Out:
#      path                                                url  noplaylist
# 0   뱀서라이크  https://www.youtube.com/playlist?list=PLO-mt5I...       False
# 1   비행기슈팅  https://www.youtube.com/playlist?list=PLO-mt5I...       False
# 2  탑다운RPG  https://www.youtube.com/playlist?list=PLO-mt5I...       False
# 3    플랫포머  https://www.youtube.com/playlist?list=PLO-mt5I...       False
# 4    유니티6  https://www.youtube.com/watch?v=350EWYC_1ZA&li...        True

# %%
for row in video_parse_list.itertuples(index=False):
    path = row.path
    url = row.url
    noplaylist = row.noplaylist
    print(f"Path: {path}, URL: {url}, noplaylist: {noplaylist}")
# Out:
# Path: 뱀서라이크, URL: https://www.youtube.com/playlist?list=PLO-mt5Iu5TeZF8xMHqtT_DhAPKmjF6i3x, noplaylist: False
# Path: 비행기슈팅, URL: https://www.youtube.com/playlist?list=PLO-mt5Iu5TeYtWvM9eN-xnwRbyUAMWd3b, noplaylist: False
# Path: 탑다운RPG, URL: https://www.youtube.com/playlist?list=PLO-mt5Iu5TeYfyXsi6kzHK8kfjPvadC5u, noplaylist: False
# Path: 플랫포머, URL: https://www.youtube.com/playlist?list=PLO-mt5Iu5TeZGR_y6mHmTWyo0RyGgO0N_, noplaylist: False
# Path: 유니티6, URL: https://www.youtube.com/watch?v=350EWYC_1ZA&list=PLO-mt5Iu5TeZWoYS0KENkohpFgjMnUBgk&index=1, noplaylist: True
# Path: 유니티6, URL: https://www.youtube.com/watch?v=Q7mHfbEzaJM&list=PLO-mt5Iu5TeZWoYS0KENkohpFgjMnUBgk&index=2, noplaylist: True
# Path: 유니티6, URL: https://www.youtube.com/watch?v=r4aZypBrFHE, noplaylist: True
# Path: 유니티6, URL: https://www.youtube.com/watch?v=3mSO1sMdGxM, noplaylist: True

# %%
import yt_dlp
import os

def get_video_or_playlist_info(url, noplaylist=True):
    """
    입력된 URL이 재생목록인지 단일 동영상인지 확인하고 정보를 반환합니다.
    :param url: 유튜브 URL
    :param noplaylist: True일 경우 재생목록을 단일 동영상으로 처리
    :return: 동영상 또는 재생목록의 정보
    """
    ydl_opts = {
        'quiet': True,
        'extract_flat': not noplaylist,  # 재생목록일 경우 정보만 가져옴
        'noplaylist': noplaylist,  # 사용자의 선택에 따라 재생목록 전체 또는 단일 동영상 처리
        'geo_bypass': True,  # 지역 제한 우회
        'geo_bypass_country': 'KR',  # 한국 지역으로 설정
        'http_headers': {
            'Accept-Language': 'ko'  # HTTP 요청에 한국어 설정
        }
    }
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(url, download=False)
        return info


def download_audio(youtube_url: str, output_path: str = "./", noplaylist=True) -> None:
    """
    유튜브 동영상에서 오디오만 다운로드합니다.
    :param youtube_url: 유튜브 동영상 또는 재생목록 URL
    :param output_path: 오디오 파일이 저장될 경로
    :param noplaylist: True일 경우 재생목록을 단일 동영상으로 처리
    """
    # 디렉토리가 없으면 생성
    os.makedirs(output_path, exist_ok=True)

    # URL 정보 가져오기
    info = get_video_or_playlist_info(youtube_url, noplaylist=noplaylist)

    # 단일 동영상 처리
    if 'entries' not in info:
        title = info.get('title', 'Unknown Title')  # 타이틀 자동 추출
        file_path = os.path.join(output_path, f"{title}.mp3")

        # 파일이 존재하는지 확인
        if os.path.exists(file_path):
            print(f"파일이 이미 존재합니다: {file_path}")
        else:
            print(f"다운로드 중: {file_path}")
            ydl_opts = {
                'format': 'bestaudio/best',
                'postprocessors': [{
                    'key': 'FFmpegExtractAudio',
                    'preferredcodec': 'mp3',
                    'preferredquality': '192',
                }],
                'outtmpl': f'{output_path}{title}.%(ext)s',
                'quiet': False,
            }
            with yt_dlp.YoutubeDL(ydl_opts) as ydl:
                ydl.download([youtube_url])

    # 재생목록 처리
    else:
        print(f"재생목록에서 {len(info['entries'])}개의 동영상을 찾았습니다.")
        for entry in info['entries']:
            video_url = entry.get('url')
            title = entry.get('title', 'Unknown Title')  # 타이틀 자동 추출
            file_path = os.path.join(output_path, f"{title}.mp3")
            # 파일이 존재하는지 확인
            if os.path.exists(file_path):
                print(f"파일이 이미 존재합니다: {file_path}")
            else:
                print(f"다운로드 중: {file_path}")
                try:
                    ydl_opts = {
                        'format': 'bestaudio/best',
                        'postprocessors': [{
                            'key': 'FFmpegExtractAudio',
                            'preferredcodec': 'mp3',
                            'preferredquality': '192',
                        }],
                        'outtmpl': f'{output_path}{title}.%(ext)s',
                        'quiet': False,
                    }
                    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
                        ydl.download([video_url])
                except Exception as e:
                    print(f"다운로드 실패: {title}, URL: {video_url}, 에러: {e}")

for row in video_parse_list.itertuples(index=False):
    path = row.path
    url = row.url
    noplaylist = row.noplaylist

    print(f"Path: {path}, URL: {url}, noplaylist: {noplaylist}")
    download_audio(url, f'./downloads/{path}/', noplaylist)
# Out:
# Path: 뱀서라이크, URL: https://www.youtube.com/playlist?list=PLO-mt5Iu5TeZF8xMHqtT_DhAPKmjF6i3x, noplaylist: False
# WARNING: [youtube:tab] Incomplete data received. Retrying (1/3)...
# WARNING: [youtube:tab] Incomplete data received. Retrying (2/3)...
# WARNING: [youtube:tab] Incomplete data received. Retrying (3/3)...
# WARNING: [youtube:tab] Incomplete data received. Giving up after 3 retries
# 재생목록에서 22개의 동영상을 찾았습니다.
# 파일이 이미 존재합니다: ./downloads/뱀서라이크/Unity Vampire Survivors Like Dev Course is coming?!🧟Undead Survivor.mp3
# 파일이 이미 존재합니다: ./downloads/뱀서라이크/Creating🧍2D Objects [Unity Vampire Survivors Like 01].mp3
# 파일이 이미 존재합니다: ./downloads/뱀서라이크/Implementing🚶Player Movement [Unity Vampire Survivors Like 02].mp3
# 파일이 이미 존재합니다: ./downloads/뱀서라이크/Applying The New Input System🎮 [Unity Vampire Survivors Like 02+].mp3
# 파일이 이미 존재합니다: ./downloads/뱀서라이크/Creating 2D Cell Animation🏃 [Unity Vampire Survivors Like 03].mp3
# 파일이 이미 존재합니다: ./downloads/뱀서라이크/Infinite🌍 Map Movement [Unity Vampire Survivors Like 04].mp3
# 파일이 이미 존재합니다: ./downloads/뱀서라이크/Creating Monster🧟 [Unity Vampire Survivors Like 05].mp3
# 파일이 이미 존재합니다: ./downloads/뱀서라이크/Summon by object pooling🏊 [Unity Vampire Survivors Like 06].mp3
# 파일이 이미 존재합니다: ./downloads/뱀서라이크/Apply Summon Level⏳ [Unity Vampire Survivors Like 06+].mp3
# 파일이 이미 존재합니다: ./downloads/뱀서라이크/Rotating 🪓 Melee Weapon [Unity Vampire Survivors Like 07].mp3
# 파일이 이미 존재합니다: ./downloads/뱀서라이크/Automatic🎯Ranged Attacks [Unity Vampire Survivors Like 08].mp3
# 다운로드 중: ./downloads/뱀서라이크/Creating a Monster Kill With a Sense of Impact🌟 [Unity Vampire Survivors Like 09].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=JRaIlTEmvHY
# [youtube] JRaIlTEmvHY: Downloading webpage
# [youtube] JRaIlTEmvHY: Downloading tv player API JSON
# [youtube] JRaIlTEmvHY: Downloading ios player API JSON
# [youtube] JRaIlTEmvHY: Downloading m3u8 information
# [info] JRaIlTEmvHY: Downloading 1 format(s): 251
# [download] Destination: ./downloads/뱀서라이크/Creating a Monster Kill With a Sense of Impact🌟 [Unity Vampire Survivors Like 09].webm
# [download] 100% of   23.03MiB in 00:00:01 at 20.31MiB/s
# [ExtractAudio] Destination: ./downloads/뱀서라이크/Creating a Monster Kill With a Sense of Impact🌟 [Unity Vampire Survivors Like 09].mp3
# Deleting original file ./downloads/뱀서라이크/Creating a Monster Kill With a Sense of Impact🌟 [Unity Vampire Survivors Like 09].webm (pass -k to keep)
# 다운로드 중: ./downloads/뱀서라이크/Creating HUD📐 [Unity Vampire Survivors Like 10].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ip0xffLSWlk
# [youtube] ip0xffLSWlk: Downloading webpage
# [youtube] ip0xffLSWlk: Downloading tv player API JSON
# [youtube] ip0xffLSWlk: Downloading ios player API JSON
# [youtube] ip0xffLSWlk: Downloading m3u8 information
# [info] ip0xffLSWlk: Downloading 1 format(s): 251
# [download] Destination: ./downloads/뱀서라이크/Creating HUD📐 [Unity Vampire Survivors Like 10].webm
# [download] 100% of   35.05MiB in 00:00:02 at 17.16MiB/s
# [ExtractAudio] Destination: ./downloads/뱀서라이크/Creating HUD📐 [Unity Vampire Survivors Like 10].mp3
# Deleting original file ./downloads/뱀서라이크/Creating HUD📐 [Unity Vampire Survivors Like 10].webm (pass -k to keep)
# 다운로드 중: ./downloads/뱀서라이크/Ability Upgrade💪 Implementation [Unity Vampire Survivors Like 11].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=-47pjK-P888
# [youtube] -47pjK-P888: Downloading webpage
# [youtube] -47pjK-P888: Downloading tv player API JSON
# [youtube] -47pjK-P888: Downloading ios player API JSON
# [youtube] -47pjK-P888: Downloading m3u8 information
# [info] -47pjK-P888: Downloading 1 format(s): 251
# [download] Destination: ./downloads/뱀서라이크/Ability Upgrade💪 Implementation [Unity Vampire Survivors Like 11].webm
# [download] 100% of   48.84MiB in 00:00:02 at 17.00MiB/s
# [ExtractAudio] Destination: ./downloads/뱀서라이크/Ability Upgrade💪 Implementation [Unity Vampire Survivors Like 11].mp3
# Deleting original file ./downloads/뱀서라이크/Ability Upgrade💪 Implementation [Unity Vampire Survivors Like 11].webm (pass -k to keep)
# 다운로드 중: ./downloads/뱀서라이크/Expressing Player Equipped Weapons [Unity Vampire Survivors Like 11+].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=NE5j8YmJ5Ds
# [youtube] NE5j8YmJ5Ds: Downloading webpage
# [youtube] NE5j8YmJ5Ds: Downloading tv player API JSON
# [youtube] NE5j8YmJ5Ds: Downloading ios player API JSON
# [youtube] NE5j8YmJ5Ds: Downloading m3u8 information
# [info] NE5j8YmJ5Ds: Downloading 1 format(s): 251
# [download] Destination: ./downloads/뱀서라이크/Expressing Player Equipped Weapons [Unity Vampire Survivors Like 11+].webm
# [download] 100% of   15.73MiB in 00:00:00 at 24.60MiB/s
# [ExtractAudio] Destination: ./downloads/뱀서라이크/Expressing Player Equipped Weapons [Unity Vampire Survivors Like 11+].mp3
# Deleting original file ./downloads/뱀서라이크/Expressing Player Equipped Weapons [Unity Vampire Survivors Like 11+].webm (pass -k to keep)
# 다운로드 중: ./downloads/뱀서라이크/Level Up 🥳 System [Unity Vampire Survivors Like 12].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=eo8bLO7kHVo
# [youtube] eo8bLO7kHVo: Downloading webpage
# [youtube] eo8bLO7kHVo: Downloading tv player API JSON
# [youtube] eo8bLO7kHVo: Downloading ios player API JSON
# [youtube] eo8bLO7kHVo: Downloading m3u8 information
# [info] eo8bLO7kHVo: Downloading 1 format(s): 251
# [download] Destination: ./downloads/뱀서라이크/Level Up 🥳 System [Unity Vampire Survivors Like 12].webm
# [download] 100% of   34.53MiB in 00:00:02 at 16.73MiB/s
# [ExtractAudio] Destination: ./downloads/뱀서라이크/Level Up 🥳 System [Unity Vampire Survivors Like 12].mp3
# Deleting original file ./downloads/뱀서라이크/Level Up 🥳 System [Unity Vampire Survivors Like 12].webm (pass -k to keep)
# 다운로드 중: ./downloads/뱀서라이크/Game Start and End [Unity Vampire Survivors Like 13].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Lt2Q9glJlw0
# [youtube] Lt2Q9glJlw0: Downloading webpage
# [youtube] Lt2Q9glJlw0: Downloading tv player API JSON
# [youtube] Lt2Q9glJlw0: Downloading ios player API JSON
# [youtube] Lt2Q9glJlw0: Downloading m3u8 information
# [info] Lt2Q9glJlw0: Downloading 1 format(s): 251
# [download] Destination: ./downloads/뱀서라이크/Game Start and End [Unity Vampire Survivors Like 13].webm
# [download] 100% of   27.36MiB in 00:00:01 at 18.49MiB/s
# [ExtractAudio] Destination: ./downloads/뱀서라이크/Game Start and End [Unity Vampire Survivors Like 13].mp3
# Deleting original file ./downloads/뱀서라이크/Game Start and End [Unity Vampire Survivors Like 13].webm (pass -k to keep)
# 다운로드 중: ./downloads/뱀서라이크/Play Character🧑‍🤝‍🧑 Select [Unity Vampire Survivors Like 14].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=vJACbWBDa90
# [youtube] vJACbWBDa90: Downloading webpage
# [youtube] vJACbWBDa90: Downloading tv player API JSON
# [youtube] vJACbWBDa90: Downloading ios player API JSON
# [youtube] vJACbWBDa90: Downloading m3u8 information
# [info] vJACbWBDa90: Downloading 1 format(s): 251
# [download] Destination: ./downloads/뱀서라이크/Play Character🧑‍🤝‍🧑 Select [Unity Vampire Survivors Like 14].webm
# [download] 100% of   15.64MiB in 00:00:01 at 15.31MiB/s
# [ExtractAudio] Destination: ./downloads/뱀서라이크/Play Character🧑‍🤝‍🧑 Select [Unity Vampire Survivors Like 14].mp3
# Deleting original file ./downloads/뱀서라이크/Play Character🧑‍🤝‍🧑 Select [Unity Vampire Survivors Like 14].webm (pass -k to keep)
# 다운로드 중: ./downloads/뱀서라이크/Character Unlock🔓 System [Unity Vampire Survivors Like 14+].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=QxsH5fE0iAo
# [youtube] QxsH5fE0iAo: Downloading webpage
# [youtube] QxsH5fE0iAo: Downloading tv player API JSON
# [youtube] QxsH5fE0iAo: Downloading ios player API JSON
# [youtube] QxsH5fE0iAo: Downloading m3u8 information
# [info] QxsH5fE0iAo: Downloading 1 format(s): 251
# [download] Destination: ./downloads/뱀서라이크/Character Unlock🔓 System [Unity Vampire Survivors Like 14+].webm
# [download] 100% of   27.16MiB in 00:00:03 at 7.81MiB/s
# [ExtractAudio] Destination: ./downloads/뱀서라이크/Character Unlock🔓 System [Unity Vampire Survivors Like 14+].mp3
# Deleting original file ./downloads/뱀서라이크/Character Unlock🔓 System [Unity Vampire Survivors Like 14+].webm (pass -k to keep)
# 다운로드 중: ./downloads/뱀서라이크/Convenient audio🔊 system construction [Unity Vampire Survivors Like 15].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=YPEkpwPrmPk
# [youtube] YPEkpwPrmPk: Downloading webpage
# [youtube] YPEkpwPrmPk: Downloading tv player API JSON
# [youtube] YPEkpwPrmPk: Downloading ios player API JSON
# [youtube] YPEkpwPrmPk: Downloading m3u8 information
# [info] YPEkpwPrmPk: Downloading 1 format(s): 251
# [download] Destination: ./downloads/뱀서라이크/Convenient audio🔊 system construction [Unity Vampire Survivors Like 15].webm
# [download] 100% of   28.45MiB in 00:00:01 at 15.48MiB/s
# [ExtractAudio] Destination: ./downloads/뱀서라이크/Convenient audio🔊 system construction [Unity Vampire Survivors Like 15].mp3
# Deleting original file ./downloads/뱀서라이크/Convenient audio🔊 system construction [Unity Vampire Survivors Like 15].webm (pass -k to keep)
# 다운로드 중: ./downloads/뱀서라이크/Logic🛠️ Complement [Unity Vampire Survivors Like 16].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=XslHd_0oVXg
# [youtube] XslHd_0oVXg: Downloading webpage
# [youtube] XslHd_0oVXg: Downloading tv player API JSON
# [youtube] XslHd_0oVXg: Downloading ios player API JSON
# [youtube] XslHd_0oVXg: Downloading m3u8 information
# [info] XslHd_0oVXg: Downloading 1 format(s): 251
# [download] Destination: ./downloads/뱀서라이크/Logic🛠️ Complement [Unity Vampire Survivors Like 16].webm
# [download] 100% of    9.31MiB in 00:00:00 at 18.68MiB/s
# [ExtractAudio] Destination: ./downloads/뱀서라이크/Logic🛠️ Complement [Unity Vampire Survivors Like 16].mp3
# Deleting original file ./downloads/뱀서라이크/Logic🛠️ Complement [Unity Vampire Survivors Like 16].webm (pass -k to keep)
# 다운로드 중: ./downloads/뱀서라이크/Mobile📱 Build [Unity Vampire Survivors Like 17].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=O5Qvq4dypOg
# [youtube] O5Qvq4dypOg: Downloading webpage
# [youtube] O5Qvq4dypOg: Downloading tv player API JSON
# [youtube] O5Qvq4dypOg: Downloading ios player API JSON
# [youtube] O5Qvq4dypOg: Downloading m3u8 information
# [info] O5Qvq4dypOg: Downloading 1 format(s): 251
# [download] Destination: ./downloads/뱀서라이크/Mobile📱 Build [Unity Vampire Survivors Like 17].webm
# [download] 100% of   25.60MiB in 00:00:00 at 27.33MiB/s
# [ExtractAudio] Destination: ./downloads/뱀서라이크/Mobile📱 Build [Unity Vampire Survivors Like 17].mp3
# Deleting original file ./downloads/뱀서라이크/Mobile📱 Build [Unity Vampire Survivors Like 17].webm (pass -k to keep)
# Path: 비행기슈팅, URL: https://www.youtube.com/playlist?list=PLO-mt5Iu5TeYtWvM9eN-xnwRbyUAMWd3b, noplaylist: False
# WARNING: [youtube:tab] Incomplete data received. Retrying (1/3)...
# WARNING: [youtube:tab] Incomplete data received. Retrying (2/3)...
# WARNING: [youtube:tab] Incomplete data received. Retrying (3/3)...
# WARNING: [youtube:tab] Incomplete data received. Giving up after 3 retries
# 재생목록에서 12개의 동영상을 찾았습니다.
# 다운로드 중: ./downloads/비행기슈팅/2D 종스크롤 슈팅 -  플레이어 이동 구현하기 [유니티 기초 강좌 B27 + 에셋 다운로드].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ETYzjbnLixY
# [youtube] ETYzjbnLixY: Downloading webpage
# [youtube] ETYzjbnLixY: Downloading tv player API JSON
# [youtube] ETYzjbnLixY: Downloading ios player API JSON
# [youtube] ETYzjbnLixY: Downloading m3u8 information
# [info] ETYzjbnLixY: Downloading 1 format(s): 251
# [download] Destination: ./downloads/비행기슈팅/2D 종스크롤 슈팅 -  플레이어 이동 구현하기 [유니티 기초 강좌 B27 + 에셋 다운로드].webm
# [download] 100% of   36.51MiB in 00:00:03 at 10.58MiB/s
# [ExtractAudio] Destination: ./downloads/비행기슈팅/2D 종스크롤 슈팅 -  플레이어 이동 구현하기 [유니티 기초 강좌 B27 + 에셋 다운로드].mp3
# Deleting original file ./downloads/비행기슈팅/2D 종스크롤 슈팅 -  플레이어 이동 구현하기 [유니티 기초 강좌 B27 + 에셋 다운로드].webm (pass -k to keep)
# 다운로드 중: ./downloads/비행기슈팅/2D 종스크롤 슈팅 -  총알발사 구현하기 [유니티 기초 강좌 B28].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=JUG0GnsJHQw
# [youtube] JUG0GnsJHQw: Downloading webpage
# [youtube] JUG0GnsJHQw: Downloading tv player API JSON
# [youtube] JUG0GnsJHQw: Downloading ios player API JSON
# [youtube] JUG0GnsJHQw: Downloading m3u8 information
# [info] JUG0GnsJHQw: Downloading 1 format(s): 251
# [download] Destination: ./downloads/비행기슈팅/2D 종스크롤 슈팅 -  총알발사 구현하기 [유니티 기초 강좌 B28].webm
# [download] 100% of   30.97MiB in 00:00:04 at 7.51MiB/s
# [ExtractAudio] Destination: ./downloads/비행기슈팅/2D 종스크롤 슈팅 -  총알발사 구현하기 [유니티 기초 강좌 B28].mp3
# Deleting original file ./downloads/비행기슈팅/2D 종스크롤 슈팅 -  총알발사 구현하기 [유니티 기초 강좌 B28].webm (pass -k to keep)
# 다운로드 중: ./downloads/비행기슈팅/2D 종스크롤 슈팅 -  적 비행기 만들기 [유니티 기초 강좌 B29].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=lKFka1regy8
# [youtube] lKFka1regy8: Downloading webpage
# [youtube] lKFka1regy8: Downloading tv player API JSON
# [youtube] lKFka1regy8: Downloading ios player API JSON
# [youtube] lKFka1regy8: Downloading m3u8 information
# [info] lKFka1regy8: Downloading 1 format(s): 251
# [download] Destination: ./downloads/비행기슈팅/2D 종스크롤 슈팅 -  적 비행기 만들기 [유니티 기초 강좌 B29].webm
# [download] 100% of   33.20MiB in 00:00:06 at 5.12MiB/s
# [ExtractAudio] Destination: ./downloads/비행기슈팅/2D 종스크롤 슈팅 -  적 비행기 만들기 [유니티 기초 강좌 B29].mp3
# Deleting original file ./downloads/비행기슈팅/2D 종스크롤 슈팅 -  적 비행기 만들기 [유니티 기초 강좌 B29].webm (pass -k to keep)
# 다운로드 중: ./downloads/비행기슈팅/2D 종스크롤 슈팅 -  적 전투와 피격 이벤트 만들기 [유니티 기초 강좌 B30].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=OI7BvnN4zLE
# [youtube] OI7BvnN4zLE: Downloading webpage
# [youtube] OI7BvnN4zLE: Downloading tv player API JSON
# [youtube] OI7BvnN4zLE: Downloading ios player API JSON
# [youtube] OI7BvnN4zLE: Downloading m3u8 information
# [info] OI7BvnN4zLE: Downloading 1 format(s): 251
# [download] Destination: ./downloads/비행기슈팅/2D 종스크롤 슈팅 -  적 전투와 피격 이벤트 만들기 [유니티 기초 강좌 B30].webm
# [download] 100% of   30.61MiB in 00:00:04 at 7.47MiB/s
# [ExtractAudio] Destination: ./downloads/비행기슈팅/2D 종스크롤 슈팅 -  적 전투와 피격 이벤트 만들기 [유니티 기초 강좌 B30].mp3
# Deleting original file ./downloads/비행기슈팅/2D 종스크롤 슈팅 -  적 전투와 피격 이벤트 만들기 [유니티 기초 강좌 B30].webm (pass -k to keep)
# 다운로드 중: ./downloads/비행기슈팅/2D 종스크롤 슈팅 -  UI 간단하게 완성하기 [유니티 기초 강좌 B31].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=qXa7y1Que6s
# [youtube] qXa7y1Que6s: Downloading webpage
# [youtube] qXa7y1Que6s: Downloading tv player API JSON
# [youtube] qXa7y1Que6s: Downloading ios player API JSON
# [youtube] qXa7y1Que6s: Downloading m3u8 information
# [info] qXa7y1Que6s: Downloading 1 format(s): 251
# [download] Destination: ./downloads/비행기슈팅/2D 종스크롤 슈팅 -  UI 간단하게 완성하기 [유니티 기초 강좌 B31].webm
# [download] 100% of   24.08MiB in 00:00:02 at 11.57MiB/s
# [ExtractAudio] Destination: ./downloads/비행기슈팅/2D 종스크롤 슈팅 -  UI 간단하게 완성하기 [유니티 기초 강좌 B31].mp3
# Deleting original file ./downloads/비행기슈팅/2D 종스크롤 슈팅 -  UI 간단하게 완성하기 [유니티 기초 강좌 B31].webm (pass -k to keep)
# 다운로드 중: ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 아이템과 필살기 구현하기 [유니티 기초 강좌 B32].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=RLbcov_aGfo
# [youtube] RLbcov_aGfo: Downloading webpage
# [youtube] RLbcov_aGfo: Downloading tv player API JSON
# [youtube] RLbcov_aGfo: Downloading ios player API JSON
# [youtube] RLbcov_aGfo: Downloading m3u8 information
# [info] RLbcov_aGfo: Downloading 1 format(s): 251
# [download] Destination: ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 아이템과 필살기 구현하기 [유니티 기초 강좌 B32].webm
# [download] 100% of   40.55MiB in 00:00:03 at 12.30MiB/s
# [ExtractAudio] Destination: ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 아이템과 필살기 구현하기 [유니티 기초 강좌 B32].mp3
# Deleting original file ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 아이템과 필살기 구현하기 [유니티 기초 강좌 B32].webm (pass -k to keep)
# 다운로드 중: ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 원근감있는 무한 배경 만들기 [유니티 기초 강좌 B33].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=KUQAULcpYZU
# [youtube] KUQAULcpYZU: Downloading webpage
# [youtube] KUQAULcpYZU: Downloading tv player API JSON
# [youtube] KUQAULcpYZU: Downloading ios player API JSON
# [youtube] KUQAULcpYZU: Downloading m3u8 information
# [info] KUQAULcpYZU: Downloading 1 format(s): 251
# [download] Destination: ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 원근감있는 무한 배경 만들기 [유니티 기초 강좌 B33].webm
# [download] 100% of   19.99MiB in 00:00:03 at 6.09MiB/s
# [ExtractAudio] Destination: ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 원근감있는 무한 배경 만들기 [유니티 기초 강좌 B33].mp3
# Deleting original file ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 원근감있는 무한 배경 만들기 [유니티 기초 강좌 B33].webm (pass -k to keep)
# 다운로드 중: ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 최적화의 기본, 오브젝트 풀링 (어려움!) [유니티 기초 강좌 B34].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=x-5eHMRSgeg
# [youtube] x-5eHMRSgeg: Downloading webpage
# [youtube] x-5eHMRSgeg: Downloading tv player API JSON
# [youtube] x-5eHMRSgeg: Downloading ios player API JSON
# [youtube] x-5eHMRSgeg: Downloading m3u8 information
# [info] x-5eHMRSgeg: Downloading 1 format(s): 251
# [download] Destination: ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 최적화의 기본, 오브젝트 풀링 (어려움!) [유니티 기초 강좌 B34].webm
# [download] 100% of   31.97MiB in 00:00:03 at 8.84MiB/s
# [ExtractAudio] Destination: ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 최적화의 기본, 오브젝트 풀링 (어려움!) [유니티 기초 강좌 B34].mp3
# Deleting original file ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 최적화의 기본, 오브젝트 풀링 (어려움!) [유니티 기초 강좌 B34].webm (pass -k to keep)
# 다운로드 중: ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 텍스트파일을 이용한 커스텀 배치 구현 [유니티 기초 강좌 B35].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yBjsGYUdyAA
# [youtube] yBjsGYUdyAA: Downloading webpage
# [youtube] yBjsGYUdyAA: Downloading tv player API JSON
# [youtube] yBjsGYUdyAA: Downloading ios player API JSON
# [youtube] yBjsGYUdyAA: Downloading m3u8 information
# [info] yBjsGYUdyAA: Downloading 1 format(s): 251
# [download] Destination: ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 텍스트파일을 이용한 커스텀 배치 구현 [유니티 기초 강좌 B35].webm
# [download] 100% of   21.25MiB in 00:00:01 at 13.58MiB/s
# [ExtractAudio] Destination: ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 텍스트파일을 이용한 커스텀 배치 구현 [유니티 기초 강좌 B35].mp3
# Deleting original file ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 텍스트파일을 이용한 커스텀 배치 구현 [유니티 기초 강좌 B35].webm (pass -k to keep)
# 다운로드 중: ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 따라다니는 보조무기 만들기 [유니티 기초 강좌 B36].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=QPwF2Lsf7c8
# [youtube] QPwF2Lsf7c8: Downloading webpage
# [youtube] QPwF2Lsf7c8: Downloading tv player API JSON
# [youtube] QPwF2Lsf7c8: Downloading ios player API JSON
# [youtube] QPwF2Lsf7c8: Downloading m3u8 information
# [info] QPwF2Lsf7c8: Downloading 1 format(s): 251
# [download] Destination: ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 따라다니는 보조무기 만들기 [유니티 기초 강좌 B36].webm
# [download] 100% of   24.68MiB in 00:00:02 at 8.74MiB/s
# [ExtractAudio] Destination: ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 따라다니는 보조무기 만들기 [유니티 기초 강좌 B36].mp3
# Deleting original file ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 따라다니는 보조무기 만들기 [유니티 기초 강좌 B36].webm (pass -k to keep)
# 다운로드 중: ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 탄막을 뿜어대는 보스 만들기 [유니티 기초 강좌 B37].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=dnMVMBVpgYA
# [youtube] dnMVMBVpgYA: Downloading webpage
# [youtube] dnMVMBVpgYA: Downloading tv player API JSON
# [youtube] dnMVMBVpgYA: Downloading ios player API JSON
# [youtube] dnMVMBVpgYA: Downloading m3u8 information
# [info] dnMVMBVpgYA: Downloading 1 format(s): 251
# [download] Destination: ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 탄막을 뿜어대는 보스 만들기 [유니티 기초 강좌 B37].webm
# [download] 100% of   46.34MiB in 00:00:03 at 12.80MiB/s
# [ExtractAudio] Destination: ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 탄막을 뿜어대는 보스 만들기 [유니티 기초 강좌 B37].mp3
# Deleting original file ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 탄막을 뿜어대는 보스 만들기 [유니티 기초 강좌 B37].webm (pass -k to keep)
# 다운로드 중: ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 모바일 슈팅게임 만들기 [유니티 기초 강좌 BE4].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=wM2IfVuEYYE
# [youtube] wM2IfVuEYYE: Downloading webpage
# [youtube] wM2IfVuEYYE: Downloading tv player API JSON
# [youtube] wM2IfVuEYYE: Downloading ios player API JSON
# [youtube] wM2IfVuEYYE: Downloading m3u8 information
# [info] wM2IfVuEYYE: Downloading 1 format(s): 251
# [download] Destination: ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 모바일 슈팅게임 만들기 [유니티 기초 강좌 BE4].webm
# [download] 100% of   77.12MiB in 00:00:05 at 13.08MiB/s
# [ExtractAudio] Destination: ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 모바일 슈팅게임 만들기 [유니티 기초 강좌 BE4].mp3
# Deleting original file ./downloads/비행기슈팅/2D 종스크롤 슈팅 - 모바일 슈팅게임 만들기 [유니티 기초 강좌 BE4].webm (pass -k to keep)
# Path: 탑다운RPG, URL: https://www.youtube.com/playlist?list=PLO-mt5Iu5TeYfyXsi6kzHK8kfjPvadC5u, noplaylist: False
# WARNING: [youtube:tab] Incomplete data received. Retrying (1/3)...
# WARNING: [youtube:tab] Incomplete data received. Retrying (2/3)...
# WARNING: [youtube:tab] Incomplete data received. Retrying (3/3)...
# WARNING: [youtube:tab] Incomplete data received. Giving up after 3 retries
# 재생목록에서 8개의 동영상을 찾았습니다.
# 다운로드 중: ./downloads/탑다운RPG/탑다운 2D RPG - 도트 타일맵으로 쉽게 준비하기 [유니티 기초 강좌 B20 + 에셋 다운로드].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=JY-KFx3OsJo
# [youtube] JY-KFx3OsJo: Downloading webpage
# [youtube] JY-KFx3OsJo: Downloading tv player API JSON
# [youtube] JY-KFx3OsJo: Downloading ios player API JSON
# [youtube] JY-KFx3OsJo: Downloading m3u8 information
# [info] JY-KFx3OsJo: Downloading 1 format(s): 251
# [download] Destination: ./downloads/탑다운RPG/탑다운 2D RPG - 도트 타일맵으로 쉽게 준비하기 [유니티 기초 강좌 B20 + 에셋 다운로드].webm
# [download] 100% of   14.94MiB in 00:00:01 at 12.09MiB/s
# [ExtractAudio] Destination: ./downloads/탑다운RPG/탑다운 2D RPG - 도트 타일맵으로 쉽게 준비하기 [유니티 기초 강좌 B20 + 에셋 다운로드].mp3
# Deleting original file ./downloads/탑다운RPG/탑다운 2D RPG - 도트 타일맵으로 쉽게 준비하기 [유니티 기초 강좌 B20 + 에셋 다운로드].webm (pass -k to keep)
# 다운로드 중: ./downloads/탑다운RPG/탑다운 2D RPG - 쯔꾸르식 액션 구현하기 [유니티 기초 강좌 B21].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=bZVa6C6vRBQ
# [youtube] bZVa6C6vRBQ: Downloading webpage
# [youtube] bZVa6C6vRBQ: Downloading tv player API JSON
# [youtube] bZVa6C6vRBQ: Downloading ios player API JSON
# [youtube] bZVa6C6vRBQ: Downloading m3u8 information
# [info] bZVa6C6vRBQ: Downloading 1 format(s): 251
# [download] Destination: ./downloads/탑다운RPG/탑다운 2D RPG - 쯔꾸르식 액션 구현하기 [유니티 기초 강좌 B21].webm
# [download] 100% of   25.98MiB in 00:00:04 at 5.64MiB/s
# [ExtractAudio] Destination: ./downloads/탑다운RPG/탑다운 2D RPG - 쯔꾸르식 액션 구현하기 [유니티 기초 강좌 B21].mp3
# Deleting original file ./downloads/탑다운RPG/탑다운 2D RPG - 쯔꾸르식 액션 구현하기 [유니티 기초 강좌 B21].webm (pass -k to keep)
# 다운로드 중: ./downloads/탑다운RPG/탑다운 2D RPG - 대화창 UI 구축하기 [유니티 기초 강좌 B22].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=jVBiGhlwhZg
# [youtube] jVBiGhlwhZg: Downloading webpage
# [youtube] jVBiGhlwhZg: Downloading tv player API JSON
# [youtube] jVBiGhlwhZg: Downloading ios player API JSON
# [youtube] jVBiGhlwhZg: Downloading m3u8 information
# [info] jVBiGhlwhZg: Downloading 1 format(s): 251
# [download] Destination: ./downloads/탑다운RPG/탑다운 2D RPG - 대화창 UI 구축하기 [유니티 기초 강좌 B22].webm
# [download] 100% of   30.79MiB in 00:00:03 at 8.52MiB/s
# [ExtractAudio] Destination: ./downloads/탑다운RPG/탑다운 2D RPG - 대화창 UI 구축하기 [유니티 기초 강좌 B22].mp3
# Deleting original file ./downloads/탑다운RPG/탑다운 2D RPG - 대화창 UI 구축하기 [유니티 기초 강좌 B22].webm (pass -k to keep)
# 다운로드 중: ./downloads/탑다운RPG/탑다운 2D RPG - 대화 시스템 구현하기 [유니티 기초 강좌 B23].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=qJjfYvEYKiE
# [youtube] qJjfYvEYKiE: Downloading webpage
# [youtube] qJjfYvEYKiE: Downloading tv player API JSON
# [youtube] qJjfYvEYKiE: Downloading ios player API JSON
# [youtube] qJjfYvEYKiE: Downloading m3u8 information
# [info] qJjfYvEYKiE: Downloading 1 format(s): 251
# [download] Destination: ./downloads/탑다운RPG/탑다운 2D RPG - 대화 시스템 구현하기 [유니티 기초 강좌 B23].webm
# [download] 100% of   37.00MiB in 00:00:02 at 18.40MiB/s
# [ExtractAudio] Destination: ./downloads/탑다운RPG/탑다운 2D RPG - 대화 시스템 구현하기 [유니티 기초 강좌 B23].mp3
# Deleting original file ./downloads/탑다운RPG/탑다운 2D RPG - 대화 시스템 구현하기 [유니티 기초 강좌 B23].webm (pass -k to keep)
# 다운로드 중: ./downloads/탑다운RPG/탑다운 2D RPG - 퀘스트 시스템 구현하기 [유니티 기초 강좌 B24].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=RwndWebxbmo
# [youtube] RwndWebxbmo: Downloading webpage
# [youtube] RwndWebxbmo: Downloading tv player API JSON
# [youtube] RwndWebxbmo: Downloading ios player API JSON
# [youtube] RwndWebxbmo: Downloading m3u8 information
# [info] RwndWebxbmo: Downloading 1 format(s): 251
# [download] Destination: ./downloads/탑다운RPG/탑다운 2D RPG - 퀘스트 시스템 구현하기 [유니티 기초 강좌 B24].webm
# [download] 100% of   40.60MiB in 00:00:09 at 4.29MiB/s
# [ExtractAudio] Destination: ./downloads/탑다운RPG/탑다운 2D RPG - 퀘스트 시스템 구현하기 [유니티 기초 강좌 B24].mp3
# Deleting original file ./downloads/탑다운RPG/탑다운 2D RPG - 퀘스트 시스템 구현하기 [유니티 기초 강좌 B24].webm (pass -k to keep)
# 다운로드 중: ./downloads/탑다운RPG/탑다운 2D RPG - 대화 애니메이션 느낌있게 만들기 [유니티 기초 강좌 B25].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=emGwkkM6bnc
# [youtube] emGwkkM6bnc: Downloading webpage
# [youtube] emGwkkM6bnc: Downloading tv player API JSON
# [youtube] emGwkkM6bnc: Downloading ios player API JSON
# [youtube] emGwkkM6bnc: Downloading m3u8 information
# [info] emGwkkM6bnc: Downloading 1 format(s): 251
# [download] Destination: ./downloads/탑다운RPG/탑다운 2D RPG - 대화 애니메이션 느낌있게 만들기 [유니티 기초 강좌 B25].webm
# [download] 100% of   36.38MiB in 00:00:03 at 11.18MiB/s
# [ExtractAudio] Destination: ./downloads/탑다운RPG/탑다운 2D RPG - 대화 애니메이션 느낌있게 만들기 [유니티 기초 강좌 B25].mp3
# Deleting original file ./downloads/탑다운RPG/탑다운 2D RPG - 대화 애니메이션 느낌있게 만들기 [유니티 기초 강좌 B25].webm (pass -k to keep)
# 다운로드 중: ./downloads/탑다운RPG/탑다운 2D RPG - 서브메뉴와 저장기능 만들기 [유니티 기초 강좌 B26].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=mYjUVmws2F0
# [youtube] mYjUVmws2F0: Downloading webpage
# [youtube] mYjUVmws2F0: Downloading tv player API JSON
# [youtube] mYjUVmws2F0: Downloading ios player API JSON
# [youtube] mYjUVmws2F0: Downloading m3u8 information
# [info] mYjUVmws2F0: Downloading 1 format(s): 251
# [download] Destination: ./downloads/탑다운RPG/탑다운 2D RPG - 서브메뉴와 저장기능 만들기 [유니티 기초 강좌 B26].webm
# [download] 100% of   25.59MiB in 00:00:01 at 18.44MiB/s
# [ExtractAudio] Destination: ./downloads/탑다운RPG/탑다운 2D RPG - 서브메뉴와 저장기능 만들기 [유니티 기초 강좌 B26].mp3
# Deleting original file ./downloads/탑다운RPG/탑다운 2D RPG - 서브메뉴와 저장기능 만들기 [유니티 기초 강좌 B26].webm (pass -k to keep)
# 다운로드 중: ./downloads/탑다운RPG/탑다운 2D RPG - 모바일 UI & 안드로이드 빌드 [유니티 기초 강좌 BE3].mp3
# [youtube] Extracting URL: https://www.youtube.com/watch?v=IJxc-ANxO-w
# [youtube] IJxc-ANxO-w: Downloading webpage
# [youtube] IJxc-ANxO-w: Downloading tv player API JSON
# [youtube] IJxc-ANxO-w: Downloading ios player API JSON
# [youtube] IJxc-ANxO-w: Downloading m3u8 information
# [info] IJxc-ANxO-w: Downloading 1 format(s): 251
# [download] Destination: ./downloads/탑다운RPG/탑다운 2D RPG - 모바일 UI & 안드로이드 빌드 [유니티 기초 강좌 BE3].webm
# [download] 100% of   32.11MiB in 00:00:01 at 18.39MiB/s
# [ExtractAudio] Destination: ./downloads/탑다운RPG/탑다운 2D RPG - 모바일 UI & 안드로이드 빌드 [유니티 기초 강좌 BE3].mp3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 96
#      93 noplaylist = row.noplaylist
#      95 print(f"Path: {path}, URL: {url}, noplaylist: {noplaylist}")
# ---> 96 download_audio(url, f'./downloads/{path}/', noplaylist)
#
# Cell In[45], line 86, in download_audio(youtube_url, output_path, noplaylist)
#      75     ydl_opts = {
#      76         'format': 'bestaudio/best',
#      77         'postprocessors': [{
#    (...)
#      83         'quiet': False,
#      84     }
#      85     with yt_dlp.YoutubeDL(ydl_opts) as ydl:
# ---> 86         ydl.download([video_url])
#      87 except Exception as e:
#      88     print(f"다운로드 실패: {title}, URL: {video_url}, 에러: {e}")
#
# File /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:3618, in YoutubeDL.download(self, url_list)
#    3615     raise SameFileError(outtmpl)
#    3617 for url in url_list:
# -> 3618     self.__download_wrapper(self.extract_info)(
#    3619         url, force_generic_extractor=self.params.get('force_generic_extractor', False))
#    3621 return self._download_retcode
#
# File /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:3591, in YoutubeDL.__download_wrapper.<locals>.wrapper(*args, **kwargs)
#    3588 @functools.wraps(func)
#    3589 def wrapper(*args, **kwargs):
#    3590     try:
# -> 3591         res = func(*args, **kwargs)
#    3592     except CookieLoadError:
#    3593         raise
#
# File /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:1626, in YoutubeDL.extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1624             raise ExistingVideoReached
#    1625         break
# -> 1626     return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1627 else:
#    1628     extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# File /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:1637, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1635 while True:
#    1636     try:
# -> 1637         return func(self, *args, **kwargs)
#    1638     except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1639         raise
#
# File /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:1793, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#    1791 if process:
#    1792     self._wait_for_video(ie_result)
# -> 1793     return self.process_ie_result(ie_result, download, extra_info)
#    1794 else:
#    1795     return ie_result
#
# File /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:1852, in YoutubeDL.process_ie_result(self, ie_result, download, extra_info)
#    1850 if result_type == 'video':
#    1851     self.add_extra_info(ie_result, extra_info)
# -> 1852     ie_result = self.process_video_result(ie_result, download=download)
#    1853     self._raise_pending_errors(ie_result)
#    1854     additional_urls = (ie_result or {}).get('additional_urls')
#
# File /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:3024, in YoutubeDL.process_video_result(self, info_dict, download)
#    3022 downloaded_formats.append(new_info)
#    3023 try:
# -> 3024     self.process_info(new_info)
#    3025 except MaxDownloadsReached:
#    3026     max_downloads_reached = True
#
# File /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:177, in _catch_unsafe_extension_error.<locals>.wrapper(self, *args, **kwargs)
#     174 @functools.wraps(func)
#     175 def wrapper(self, *args, **kwargs):
#     176     try:
# --> 177         return func(self, *args, **kwargs)
#     178     except _UnsafeExtensionError as error:
#     179         self.report_error(
#     180             f'The extracted extension ({error.extension!r}) is unusual '
#     181             'and will be skipped for safety reasons. '
#     182             f'If you believe this is an error{bug_reports_message(",")}')
#
# File /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:3570, in YoutubeDL.process_info(self, info_dict)
#    3568 fixup()
#    3569 try:
# -> 3570     replace_info_dict(self.post_process(dl_filename, info_dict, files_to_move))
#    3571 except PostProcessingError as err:
#    3572     self.report_error(f'Postprocessing: {err}')
#
# File /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:3754, in YoutubeDL.post_process(self, filename, info, files_to_move)
#    3752 info['filepath'] = filename
#    3753 info['__files_to_move'] = files_to_move or {}
# -> 3754 info = self.run_all_pps('post_process', info, additional_pps=info.get('__postprocessors'))
#    3755 info = self.run_pp(MoveFilesAfterDownloadPP(self), info)
#    3756 del info['__files_to_move']
#
# File /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:3736, in YoutubeDL.run_all_pps(self, key, info, additional_pps)
#    3734     self._forceprint(key, info)
#    3735 for pp in (additional_pps or []) + self._pps[key]:
# -> 3736     info = self.run_pp(pp, info)
#    3737 return info
#
# File /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages/yt_dlp/YoutubeDL.py:3714, in YoutubeDL.run_pp(self, pp, infodict)
#    3712     infodict['__files_to_move'] = {}
#    3713 try:
# -> 3714     files_to_delete, infodict = pp.run(infodict)
#    3715 except PostProcessingError as e:
#    3716     # Must be True and not 'only_download'
#    3717     if self.params.get('ignoreerrors') is True:
#
# File /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages/yt_dlp/postprocessor/common.py:22, in PostProcessorMetaClass.run_wrapper.<locals>.run(self, info, *args, **kwargs)
#      20 info_copy = self._copy_infodict(info)
#      21 self._hook_progress({'status': 'started'}, info_copy)
# ---> 22 ret = func(self, info, *args, **kwargs)
#      23 if ret is not None:
#      24     _, info = ret
#
# File /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages/yt_dlp/postprocessor/common.py:127, in PostProcessor._restrict_to.<locals>.decorator.<locals>.wrapper(self, info)
#     122 format_type = (
#     123     'video' if info.get('vcodec') != 'none'
#     124     else 'audio' if info.get('acodec') != 'none'
#     125     else 'images')
#     126 if allowed[format_type]:
# --> 127     return func(self, info)
#     128 else:
#     129     self.to_screen(f'Skipping {format_type}')
#
# File /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages/yt_dlp/postprocessor/ffmpeg.py:530, in FFmpegExtractAudioPP.run(self, information)
#     527     return [], information
#     529 self.to_screen(f'Destination: {new_path}')
# --> 530 self.run_ffmpeg(path, temp_path, acodec, more_opts)
#     532 os.replace(path, orig_path)
#     533 os.replace(temp_path, new_path)
#
# File /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages/yt_dlp/postprocessor/ffmpeg.py:479, in FFmpegExtractAudioPP.run_ffmpeg(self, path, out_path, codec, more_opts)
#     477 opts = ['-vn', *acodec_opts, *more_opts]
#     478 try:
# --> 479     FFmpegPostProcessor.run_ffmpeg(self, path, out_path, opts)
#     480 except FFmpegPostProcessorError as err:
#     481     raise PostProcessingError(f'audio conversion failed: {err.msg}')
#
# File /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages/yt_dlp/postprocessor/ffmpeg.py:374, in FFmpegPostProcessor.run_ffmpeg(self, path, out_path, opts, **kwargs)
#     373 def run_ffmpeg(self, path, out_path, opts, **kwargs):
# --> 374     return self.run_ffmpeg_multiple_files([path], out_path, opts, **kwargs)
#
# File /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages/yt_dlp/postprocessor/ffmpeg.py:329, in FFmpegPostProcessor.run_ffmpeg_multiple_files(self, input_paths, out_path, opts, **kwargs)
#     328 def run_ffmpeg_multiple_files(self, input_paths, out_path, opts, **kwargs):
# --> 329     return self.real_run_ffmpeg(
#     330         [(path, []) for path in input_paths],
#     331         [(out_path, opts)], **kwargs)
#
# File /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages/yt_dlp/postprocessor/ffmpeg.py:363, in FFmpegPostProcessor.real_run_ffmpeg(self, input_path_opts, output_path_opts, expected_retcodes)
#     358     cmd += itertools.chain.from_iterable(
#     359         make_args(path, list(opts), arg_type, i + 1)
#     360         for i, (path, opts) in enumerate(path_opts) if path)
#     362 self.write_debug(f'ffmpeg command line: {shell_quote(cmd)}')
# --> 363 _, stderr, returncode = Popen.run(
#     364     cmd, text=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, stdin=subprocess.PIPE)
#     365 if returncode not in variadic(expected_retcodes):
#     366     self.write_debug(stderr)
#
# File /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages/yt_dlp/utils/_utils.py:906, in Popen.run(cls, timeout, *args, **kwargs)
#     904 with cls(*args, **kwargs) as proc:
#     905     default = '' if proc.__text_mode else b''
# --> 906     stdout, stderr = proc.communicate_or_kill(timeout=timeout)
#     907     return stdout or default, stderr or default, proc.returncode
#
# File /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages/yt_dlp/utils/_utils.py:892, in Popen.communicate_or_kill(self, *args, **kwargs)
#     890 def communicate_or_kill(self, *args, **kwargs):
#     891     try:
# --> 892         return self.communicate(*args, **kwargs)
#     893     except BaseException:  # Including KeyboardInterrupt
#     894         self.kill(timeout=None)
#
# File /opt/miniconda3/envs/hanghae99/lib/python3.10/subprocess.py:1154, in Popen.communicate(self, input, timeout)
#    1151     endtime = None
#    1153 try:
# -> 1154     stdout, stderr = self._communicate(input, endtime, timeout)
#    1155 except KeyboardInterrupt:
#    1156     # https://bugs.python.org/issue25942
#    1157     # See the detailed comment in .wait().
#    1158     if timeout is not None:
#
# File /opt/miniconda3/envs/hanghae99/lib/python3.10/subprocess.py:2021, in Popen._communicate(self, input, endtime, orig_timeout)
#    2014     self._check_timeout(endtime, orig_timeout,
#    2015                         stdout, stderr,
#    2016                         skip_check_and_raise=True)
#    2017     raise RuntimeError(  # Impossible :)
#    2018         '_check_timeout(..., skip_check_and_raise=True) '
#    2019         'failed to raise TimeoutExpired.')
# -> 2021 ready = selector.select(timeout)
#    2022 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2024 # XXX Rewrite these to use non-blocking I/O on the file
#    2025 # objects; they are no longer using C stdio!
#
# File /opt/miniconda3/envs/hanghae99/lib/python3.10/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:
