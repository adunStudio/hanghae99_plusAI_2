# %%
import json
import time
import torch
import transformers
import wandb
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
import nltk
from transformers import BitsAndBytesConfig
from transformers import AutoModelForCausalLM
from transformers import AutoTokenizer


# nltk 다운로드 (최초 1회)
nltk.download('punkt')

# wandb 초기화
wandb.init(project="hangae_Final", name="5B_4Bit_Quant")

# corpus.json 파일 로드 (UTF-8 인코딩)
with open("./corpus.json", "r", encoding="utf-8") as f:
    evaluation_data = json.load(f)

# 10개만 추론
evaluation_data = evaluation_data[:10]

# 허깅페이스 방식으로 모델 및 파이프라인 초기화
model_id = "Bllossom/llama-3.2-Korean-Bllossom-AICA-5B"
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    quantization_config=quantization_config, # 4비트 양자화 적용
    device_map="auto"
)
tokenizer = AutoTokenizer.from_pretrained(
    model_id,
    trust_remote_code=True
)
generator = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    device_map="auto",
)
generator.model.eval()

# 시스템 프롬프트 정의
SYSTEM_PROMPT = (
    "You are a helpful AI assistant. Please answer the user's questions kindly. "
    "당신은 유능한 AI 어시스턴트 입니다. 사용자의 질문에 대해 친절하게 답변해주세요."
)

# 채팅 템플릿을 적용하여 프롬프트를 생성하는 함수
def make_prompt(system_msg: str, user_msg: str) -> str:

    msg = f"""
다음은 유튜브 타임라인 요약 문서입니다. 이 내용을 분석하여 10개의 핵심 용어(KeyPoint)와 설명을 생성하세요.
설명을 생성할 때 영상 위주가 아닌 최대한 전문적이고 구체적으로 추가 설명해주세요. 저는 영상 내용 뿐 아니라 그 용어에 대한 내용을 알고 싶습니다.
중요하지 않더라도 알면 좋을 추가 핵심 용어도 더해주세요.

[타임라인 요약]:
{user_msg}

[가이드]:
- 필드는 `term`과 `description`을 포함하며, 결과는  10개의 키포인트 리스트로 구성됩니다.
- 반드시 JSON 형식에 맞춰 반환하세요.
- 다른 텍스트는 포함하지 마세요.

[예시]:
{evaluation_data[0]['output']}
"""

    messages = [
        {"role": "system", "content": system_msg},
        {"role": "user", "content": msg}
    ]
    prompt = generator.tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )
    return prompt

# 종료 토큰 설정
terminators = [
    generator.tokenizer.eos_token_id,
    generator.tokenizer.convert_tokens_to_ids("<|eot_id|>")
]

print(f'{round(generator.model.get_memory_footprint() / (1024 ** 3), 1)}GB')
wandb.log({"basic_memory": round(generator.model.get_memory_footprint() / (1024 ** 3), 1)})

# 평가 루프: corpus.json에 있는 각 예제에 대해 추론 수행
for idx, example in enumerate(evaluation_data):
    print(f"\n==== Example {idx+1} ====")

    # 사용자 입력과 프롬프트 생성
    user_input = example["input"]
    prompt = make_prompt(SYSTEM_PROMPT, user_input)

    # 입력 토큰 인코딩
    encoded_input = generator.tokenizer(prompt, return_tensors="pt")
    encoded_input = {k: v.to(generator.model.device) for k, v in encoded_input.items()}
    prompt_length = encoded_input["input_ids"].shape[1]

    # 속도 및 메모리 측정을 위한 시작 시간 기록 및 GPU 메모리 초기화
    start_time = time.time()
    if torch.cuda.is_available():
        torch.cuda.reset_peak_memory_stats(generator.model.device)

    # 모델 생성: 토큰별 score 반환 포함
    outputs = generator.model.generate(
        **encoded_input,
        max_new_tokens=1024,
        eos_token_id=terminators[0],
        do_sample=True,
        temperature=0.6,
        top_p=0.9,
        return_dict_in_generate=True,
        output_scores=True,
    )

    # GPU 동기화 후 종료 시간 기록
    if torch.cuda.is_available():
        torch.cuda.synchronize(generator.model.device)
    end_time = time.time()
    elapsed_time = end_time - start_time

    # GPU 메모리 사용량 측정 (Peak 메모리, MB 단위)
    if torch.cuda.is_available():
        peak_memory = round(torch.cuda.max_memory_allocated(generator.model.device) / (1024 ** 3), 1)
    else:
        peak_memory = 0

    # 생성된 전체 토큰에서 프롬프트 이후의 candidate 토큰 추출
    generated_ids = outputs.sequences[0]
    candidate_ids = generated_ids[prompt_length:]
    candidate_text = generator.tokenizer.decode(candidate_ids, skip_special_tokens=True).strip()

    print("Candidate output:")
    print(candidate_text)
    print(f"Inference Time: {elapsed_time:.2f} seconds")
    print(f"Peak GPU Memory Usage: {peak_memory:.2f} GB")

    # 참조 텍스트: evaluation_data의 "output"을 JSON 문자열로 변환
    reference_text = json.dumps(example["output"], ensure_ascii=False, indent=2)

    # BLEU 점수 계산 (공백 기준 토큰화)
    candidate_tokens = candidate_text.split()
    reference_tokens = reference_text.split()
    bleu = sentence_bleu(
        [reference_tokens],
        candidate_tokens,
        smoothing_function=SmoothingFunction().method1
    )
    print(f"BLEU score: {bleu:.4f}")

    # 로그 확률 계산: 각 생성 토큰에 대해 log‑softmax 후 선택된 토큰의 로그 확률 합산
    log_score = 0.0
    for i, step_scores in enumerate(outputs.scores):
        log_probs = torch.log_softmax(step_scores, dim=-1)
        token_id = candidate_ids[i].unsqueeze(0)  # shape: (1,)
        token_log_prob = log_probs[0, token_id].item()
        log_score += token_log_prob
    print(f"Log probability score (sum): {log_score:.4f}")

    # wandb에 메트릭 로깅
    wandb.log({
        "example_index": idx,
        "BLEU_score": bleu,
        "Inference_time_sec": elapsed_time,
        "Peak_GPU_Memory_GB": peak_memory,
        "Log_probability_score": log_score
    })

wandb.finish()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# wandb: Currently logged in as: iamkimhongil92 (iamkimhongil92-lumenasoft) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/workspace/hanghae99_plusAI_2/8_advanced/wandb/run-20250213_124346-yvtssjaf</code>
# Syncing run <strong><a href='https://wandb.ai/iamkimhongil92-lumenasoft/hangae_Final/runs/yvtssjaf' target="_blank">5B_4Bit_Quant</a></strong> to <a href='https://wandb.ai/iamkimhongil92-lumenasoft/hangae_Final' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/iamkimhongil92-lumenasoft/hangae_Final' target="_blank">https://wandb.ai/iamkimhongil92-lumenasoft/hangae_Final</a>
#  View run at <a href='https://wandb.ai/iamkimhongil92-lumenasoft/hangae_Final/runs/yvtssjaf' target="_blank">https://wandb.ai/iamkimhongil92-lumenasoft/hangae_Final/runs/yvtssjaf</a>
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Device set to use cuda:0
# 3.1GB
#
# ==== Example 1 ====
# From v4.47 onwards, when a model cache is to be returned, `generate` will return a `Cache` instance instead by default (as opposed to the legacy tuple of tuples format). If you want to keep returning the legacy format, please set `return_legacy_cache=True`.
# Candidate output:
# 1. **유니티**
#     - 유니티는 게임 및 시뮬레이션 개발에 널리 사용되는 엔진으로, 2D 및 3D 게임을 제작하는 데 필요한 다양한 툴과 기능을 제공합니다. 다양한 플랫폼에 배포할 수 있는 크로스 플랫폼 기능이 특징입니다.
#
# 2. **뱀서라이크**
#     - 뱀서라이크 게임 장르는 플레이어가 자신의 캐릭터를 조종하여 지속적으로 생성되는 적을 물리치고 생존을 추구하는 게임 유형으로, 주로 롤플레잉 요소를 포함합니다.
#
# 3. **에셋**
#     - 게임 개발에서 에셋은 음악, 이미지, 모델 등 게임 내에서 사용되는 요소들을 의미합니다. 에셋은 게임의 비주얼과 사운드 요소를 구축하는 중요한 역할을 합니다.
#
# 4. **스프라이트**
#     - 스프라이트는 2D 게임에서 사용되는 잘라낸 이미지나 그림을 의미합니다. 캐릭터, 아이템, 이펙트 등 다양한 요소의 비주얼을 표현할 수 있습니다.
#
# 5. **리지드 바디 2D**
#     - 리지드 바디 2D 컴포넌트는 물리적 상호작용을 위해 오브젝트에 물리적 특성을 부여하는 기능을 제공하며, 중력이나 충돌 감지 등을 설정할 수 있습니다.
#
# 6. **캡슐 콜라이더 2D**
#     - 캡슐 콜라이더 2D는 2D 공간에서 오브젝트의 물리적 경계를 정의하는 컴포넌트로, 캐릭터의 충돌 처리를 보다 쉽게 만들어 줍니다.
#
# 7. **그래비티 스케일**
#     - 그래비티 스케일은 리지드 바디 컴포넌트에서 중력의 영향을 얼마나 받을지를 결정하는 값으로, 0으로 설정하면 중력이 적용되지 않도록 할 수 있습니다.
#
# 8. **유니티 허브**
#     - 유니티 허브는 유니티 엔진의 다양한 버전을 관리하고 프로젝트를 생성할 수 있는 툴로, 버전 관리와 라이센스 관리를 돕습니다.
#
# 9. **URP (Universal Render Pipeline)**
#     - URP는 유니티에서 제공하는 렌더링 파이프라인의 하나로, 다양한 플랫폼에서 최적화된 성능을 제공하면서도 시각적으로 우수한 결과를 만들어낼 수 있게끔 설계되었습니다.
#
# 10. **스프라이트 설정**
#     - 스프라이트 설정은 스프라이트 이미지의 해상도, 필터링 등 다양한 속성을 조정하여 게임 내 비주얼 품질을 최적화하는 과정입니다.
# Inference Time: 19.93 seconds
# Peak GPU Memory Usage: 3.80 GB
# BLEU score: 0.6240
# Log probability score (sum): -6.2794
#
# ==== Example 2 ====
# Candidate output:
# ### KeyPoint Analysis
#
# 1. **C# Script Creation**
#    - **Explanation**: Unity에서 플레이어를 이동시키는 로직을 구현하기 위해 C# 스크립트를 작성합니다. 이 스크립트는 플레이어의 입력을 감지하고, 물리적 이동 로직을 구현합니다.
#
# 2. **Folder Creation for Script Management**
#    - **Explanation**: C# 스크립트를 관리하기 위해 폴더를 생성하고, 그 안에 플레이어 이름의 스크립트를 저장합니다. 이는 코드의 구조적 정렬과 유지보수를 돕습니다.
#
# 3. **Input Variable Declaration**
#    - **Explanation**: 스크립트 내에서 입력을 받는 변수를 선언합니다. 이 변수는 좌우 및 상하 방향키의 입력을 감지하여, 플레이어의 이동 방향을 결정합니다.
#
# 4. **Update Function for Input Handling**
#    - **Explanation**: 업데이트 함수 안에서 `Horizontal`과 `Vertical` 입력 값을 `input.GetAxis()` 함수로 가져옵니다. 이는 매 프레임마다 플레이어의 방향키 입력을 반영합니다.
#
# 5. **Material Management**
#    - **Explanation**: 게임 내에서 사용되는 시각 요소들을 관리하는 데 사용됩니다. 예를 들어, 스프라이트 설정, 에셋, 뱀서라이크 게임 장르 등을 포함합니다.
#
# 6. **Collider 2D**
#    - **Explanation**: 게임 내의 물리적 경계를 정의하는 데 사용됩니다. 이는 플레이어의 충돌 처리를 보다 쉽게 만들어 줍니다.
#
# 7. **Gravity Scale**
#    - **Explanation**: 리지드 바디 2D 컴포넌트에서 중력의 영향을 얼마나 받을지를 결정하는 값입니다. 0으로 설정하면 중력이 적용되지 않습니다.
#
# 8. **URP (Universal Render Pipeline)**
#    - **Explanation**: 유니티에서 제공하는 다양한 렌더링 파이프라인 중 하나로, 다양한 플랫폼에서 최적화된 성능과 시각적 품질을 제공합니다.
#
# 9. **Asset Management**
#    - **Explanation**: 게임의 비주얼과 사운드 요소를 관리하는 데 사용됩니다. 예를 들어, 에셋, 스프라이트, 뱀서라이크 게임 장르 등을 포함합니다.
#
# 10. **Script Execution**
#     - **Explanation**: 로딩이 끝날 때까지 기다리다가, 스크립트를 실행하여 플레이어의 이동 로직을 구현합니다. 이를 통해 정확한 이동 로직을 테스트할 수 있습니다.
#
# ### Additional KeyPoint (Optional)
#
# 11. **Animation Integration**
#     - **Explanation**: 이번 영상에서는 플레이어 이동에 집중하지만, 다음 시간에는 플레이어의 애니메이션을 추가하여 더욱 자연스러운 움직임을 구현할 것입니다. 이는 게임의 전체적인 플레이 경험을 향상시킵니다.
#
# 12. **Cross-Platform Functionality**
#     - **Explanation**: 유니티는 다양한 플랫폼에 배포할 수 있는 크로스 플랫폼 기능을 제공합니다. 이는 게임을 다양한 디바이스와 운영체제에서 실행할 수 있게 합니다.
# Inference Time: 23.28 seconds
# Peak GPU Memory Usage: 4.40 GB
# BLEU score: 0.0036
# Log probability score (sum): -124.6462
#
# ==== Example 3 ====
# Candidate output:
# 다음은 유튜브 타임라인 요약 문서의 핵심 용어와 설명입니다.
#
# 1. **유니티**
#    - **설명**: 유니티는 게임 및 시뮬레이션 개발에 널리 사용되는 엔진으로, 2D 및 3D 게임을 제작하는 데 필요한 다양한 툴과 기능을 제공합니다. 다양한 플랫폼에 배포할 수 있는 크로스 플랫폼 기능이 특징입니다.
#
# 2. **뱀서라이크**
#    - **설명**: 뱀서라이크 게임 장르는 플레이어가 자신의 캐릭터를 조종하여 지속적으로 생성되는 적을 물리치고 생존을 추구하는 게임 유형으로, 주로 롤플레잉 요소를 포함합니다.
#
# 3. **에셋**
#    - **설명**: 게임 개발에서 에셋은 음악, 이미지, 모델 등 게임 내에서 사용되는 요소들을 의미합니다. 에셋은 게임의 비주얼과 사운드 요소를 구축하는 중요한 역할을 합니다.
#
# 4. **스프라이트**
#    - **설명**: 스프라이트는 2D 게임에서 사용되는 잘라낸 이미지나 그림을 의미합니다. 캐릭터, 아이템, 이펙트 등 다양한 요소의 비주얼을 표현할 수 있습니다.
#
# 5. **리지드 바디 2D**
#    - **설명**: 리지드 바디 2D 컴포넌트는 물리적 상호작용을 위해 오브젝트에 물리적 특성을 부여하는 기능을 제공하며, 중력이나 충돌 감지 등을 설정할 수 있습니다.
#
# 6. **캡슐 콜라이더 2D**
#    - **설명**: 캡슐 콜라이더 2D는 2D 공간에서 오브젝트의 물리적 경계를 정의하는 컴포넌트로, 캐릭터의 충돌 처리를 보다 쉽게 만들어 줍니다.
#
# 7. **그래비티 스케일**
#    - **설명**: 그래비티 스케일은 리지드 바디 컴포넌트에서 중력의 영향을 얼마나 받을지를 결정하는 값으로, 0으로 설정하면 중력이 적용되지 않도록 할 수 있습니다.
#
# 8. **유니티 허브**
#    - **설명**: 유니티 허브는 유니티 엔진의 다양한 버전을 관리하고 프로젝트를 생성할 수 있는 툴로, 버전 관리와 라이센스 관리를 돕습니다.
#
# 9. **URP (Universal Render Pipeline)**
#    - **설명**: URP는 유니티에서 제공하는 렌더링 파이프라인의 하나로, 다양한 플랫폼에서 최적화된 성능을 제공하면서도 시각적으로 우수한 결과를 만들어낼 수 있게끔 설계되었습니다.
#
# 10. **스프라이트 설정**
#     - **설명**: 스프라이트 설정은 스프라이트 이미지의 해상도, 필터링 등 다양한 속성을 조정하여 게임 내 비주얼 품질을 최적화하는 과정입니다.
#
# 추가 핵심 용어:
# 11. **패키지 매니저**
#     - **설명**: 패키지 매니저는 유니티에서 사용되는 다양한 패키지와 라이브러리를 관리하고 설치할 수 있는 도구입니다. 이를 통해 게임에 필요한 모든 기능과 툴을 쉽게 추가할 수 있습니다.
#
# 12. **플레이어**
#     - **설명**: 플레이어는 게임 내에서 주인공을 의미합니다. 게임 개발 시 플레이어의 상태와 행동을 제어하는 것이 주요 목표입니다.
#
# 13. **키보드와 게임 패드**
#     - **설명**: 키보드와 게임 패드는 플레이어가 게임 내에서 입력을 주는 장치입니다. 키보드는 키보드 키와 마우스, 게임 패드는 게임 내에서 사용하는 입력 장치로, 플레이어의 행동을 제어하는 데 중요한 역할을 합니다.
#
# 14. **스크립트**
#     - **설명**: 스크립트는 게임 내에서 실행되는 코드로, 게임의 로직과 행동을 정의하는 문서입니다. 이를 통해 게임의 동작을 제어하고, 플레이어의 행동을 구현할 수 있습니다.
#
# 15. **벡터 변수**
#     - **설명**: 벡터 변수는 3차원 공간에서의 위치나 방향을 나타내는 변수입니다. 게임 내에서 플레이어의 이동을 제어하는 데 중요한 역할을 합니다.
# Inference Time: 33.50 seconds
# Peak GPU Memory Usage: 4.50 GB
# BLEU score: 0.0025
# Log probability score (sum): -52.1253
#
# ==== Example 4 ====
# Candidate output:
# ### 10개의 핵심 용어(KeyPoint)와 설명
#
# 1. **유니티 (Unity)**
#    - 설명: 유니티는 게임 및 시뮬레이션 개발에 널리 사용되는 엔진으로, 2D 및 3D 게임을 제작하는 데 필요한 다양한 툴과 기능을 제공합니다. 다양한 플랫폼에 배포할 수 있는 크로스 플랫폼 기능이 특징입니다.
#
# 2. **뱀서라이크 (Cocodile)**
#    - 설명: 뱀서라이크 게임 장르는 플레이어가 자신의 캐릭터를 조종하여 지속적으로 생성되는 적을 물리치고 생존을 추구하는 게임 유형으로, 주로 롤플레잉 요소를 포함합니다.
#
# 3. **에셋 (Assets)**
#    - 설명: 게임 개발에서 에셋은 음악, 이미지, 모델 등 게임 내에서 사용되는 요소들을 의미합니다. 에셋은 게임의 비주얼과 사운드 요소를 구축하는 중요한 역할을 합니다.
#
# 4. **스프라이트 (Sprites)**
#    - 설명: 스프라이트는 2D 게임에서 사용되는 잘라낸 이미지나 그림을 의미합니다. 캐릭터, 아이템, 이펙트 등 다양한 요소의 비주얼을 표현할 수 있습니다.
#
# 5. **리지드 바디 2D (Rigged Body 2D)**
#    - 설명: 리지드 바디 2D 컴포넌트는 물리적 상호작용을 위해 오브젝트에 물리적 특성을 부여하는 기능을 제공하며, 중력이나 충돌 감지 등을 설정할 수 있습니다.
#
# 6. **캡슐 콜라이더 2D (Capsule Collider 2D)**
#    - 설명: 캡슐 콜라이더 2D는 2D 공간에서 오브젝트의 물리적 경계를 정의하는 컴포넌트로, 캐릭터의 충돌 처리를 보다 쉽게 만들어 줍니다.
#
# 7. **그래비티 스케일 (Gravity Scale)**
#    - 설명: 그래비티 스케일은 리지드 바디 컴포넌트에서 중력의 영향을 얼마나 받을지를 결정하는 값으로, 0으로 설정하면 중력이 적용되지 않도록 할 수 있습니다.
#
# 8. **유니티 허브 (Unity Hub)**
#    - 설명: 유니티 허브는 유니티 엔진의 다양한 버전을 관리하고 프로젝트를 생성할 수 있는 툴로, 버전 관리와 라이센스 관리를 돕습니다.
#
# 9. **URP (Universal Render Pipeline)**
#    - 설명: URP는 유니티에서 제공하는 렌더링 파이프라인의 하나로, 다양한 플랫폼에서 최적화된 성능을 제공하면서도 시각적으로 우수한 결과를 만들어낼 수 있게끔 설계되었습니다.
#
# 10. **스프라이트 설정 (Sprite Settings)**
#     - 설명: 스프라이트 설정은 스프라이트 이미지의 해상도, 필터링 등 다양한 속성을 조정하여 게임 내 비주얼 품질을 최적화하는 과정입니다.
#
# ### 추가 핵심 용어
#
# 11. **애니메이터 (Animator)**
#     - 설명: 애니메이터는 애니메이션 상태를 관리하는 주요 요소로, 애니메이터를 활성화하기 위해 초기화를 반드시 해야 합니다. 상태 전환을 위해 변수나 트리거를 설정할 수 있습니다.
#
# 12. **스프라이트 애니메이션 (Sprite Animation)**
#     - 설명: 스프라이트 애니메이션은 여러 스프라이트를 순차적으로 재생시키는 방식으로, 애니메이션을 만드는 데 사용됩니다.
#
# 13. **플립 X (Flip X)**
#     - 설명: 플립 X는 캐릭터가 좌측 방향으로 이동할 때 플립을 적용해야 한다는 설정을 의미합니다. X 값이 -1일 때 플립을 적용해야 합니다.
#
# 14. **스프라이트 오버라이드 컨트롤러 (Sprite Overwrite Controller)**
#     - 설명: 스프라이트 오버라이드 컨트롤러는 기존 설정을 유지하면서 새로운 애니메이션만 변경할 수 있는 방법을 제공합니다.
#
# 15. **애니메이터 재활용 (Reusing Animators)**
#     - 설명: 애니메이터를 재활용하여 새로운 캐릭터에 적용하는 방법을 배웁니다. 이를 통해 효율적으로 작업할 수 있습니다.
# Inference Time: 32.23 seconds
# Peak GPU Memory Usage: 4.70 GB
# BLEU score: 0.0091
# Log probability score (sum): -46.7896
#
# ==== Example 5 ====
# Candidate output:
# ### 10 Key Points and Explanations
#
# 1. **무한 맵 생성 기능**
# - **설명**: 이 영상을 통해 무한 맵을 생성하는 방법을 구현합니다. 플레이어가 이동할 때마다 새로운 맵이 생성되도록 설정합니다.
# - **유의어**: 무한 맵, 2D 타일맵, 랜덤 타일, 타일 속성 설정, 시네머신 패키지, 카메라 팔로우, 물리 이동, 이벤트 트리거, 이전 타일 데이터 활용.
#
# 2. **타일맵 설정**
# - **설명**: Unity에서 2D 타일맵 시스템을 사용하여 맵을 설정합니다.
# - **유의어**: 타일맵, 랜덤 타일, 타일 속성, 다양한 패턴, 다양한 맵 생성.
#
# 3. **카메라 부드러운 따라가기 설정**
# - **설명**: 시네머신 패키지를 사용하여 카메라의 움직임을 매끄럽게 설정합니다.
# - **유의어**: 시네머신 패키지, 가상 카메라, 플레이어 팔로우, 물리 이동, 부드러운 카메라 움직임.
#
# 4. **이벤트 트리거 사용**
# - **설명**: '온 트리거 EXIT 2D' 이벤트를 사용하여 재배치 로직을 작성합니다.
# - **유의어**: 이벤트 트리거, 재배치 로직, 플레이어 위치와 타일맵 비교, 이동 거리 계산.
#
# 5. **맵의 끊김 방지**
# - **설명**: 이전의 타일맵 데이터를 활용하여 지속적으로 새로운 타일이 생성되도록 설정합니다.
# - **유의어**: 이전 데이터 활용, 끊김 방지, 지속적인 맵 생성.
#
# 6. **게임 실행 및 확인**
# - **설명**: 모든 설정이 끝난 후 게임을 실행하여 결과를 확인합니다.
# - **유의어**: 게임 실행, 무한 맵 작동, 카메라 동작 및 타일 재배치 확인, 비주얼 및 오류 체크.
#
# 7. **필드와 결과 형식**
# - **설명**: '필드'와 '결과'를 JSON 형식으로 반환합니다.
# - **유의어**: JSON 형식, 10개의 키포인트 리스트, 다양한 용어와 설명.
#
# 8. **유니티 엔진**
# - **설명**: 유니티는 게임 및 시뮬레이션 개발에 널리 사용되는 엔진으로, 2D 및 3D 게임을 제작하는 데 필요한 다양한 툴과 기능을 제공합니다.
# - **유의어**: 유니티, 다양한 기능, 크로스 플랫폼 기능.
#
# 9. **뱀서라이크 게임 장르**
# - **설명**: 뱀서라이크 게임 장르는 플레이어가 자신의 캐릭터를 조종하여 지속적으로 생성되는 적을 물리치고 생존을 추구하는 게임 유형입니다.
# - **유의어**: 뱀서라이크, 롤플레잉 요소, 생존 게임.
#
# 10. **에셋 및 스프라이트**
#     - **설명**: 에셋은 게임 개발에서 음악, 이미지, 모델 등 게임 내에서 사용되는 요소들을 의미합니다. 스프라이트는 2D 게임에서 사용되는 잘라낸 이미지나 그림을 의미합니다.
#     - **유의어**: 에셋, 스프라이트, 2D 게임 요소, 비주얼 및 사운드 요소.
#
# 11. **리지드 바디 2D**
#     - **설명**: 리지드 바디 2D 컴포넌트는 물리적 상호작용을 위해 오브젝트에 물리적 특성을 부여하는 기능을 제공하며, 중력이나 충돌 감지 등을 설정할 수 있습니다.
#     - **유의어**: 리지드 바디, 물리적 상호작용, 중력, 충돌 감지.
#
# 12. **캡슐 콜라이더 2D**
#     - **설명**: 캡슐 콜라이더 2D는 2D 공간에서 오브젝트의 물리적 경계를 정의하는 컴포넌트로, 캐릭터의 충돌 처리를 보다 쉽게 만들어 줍니다.
#     - **유의어**: 캡슐 콜라이더, 충돌 처리, 2D 공간.
#
# 13. **그래비티 스케일**
#     - **설명**: 그래비티 스케일은 리지드 바디 컴포넌트에서 중력의 영향을 얼마나
# Inference Time: 30.57 seconds
# Peak GPU Memory Usage: 4.70 GB
# BLEU score: 0.0026
# Log probability score (sum): -83.3956
#
# ==== Example 6 ====
# Candidate output:
# 다음은 유튜브 타임라인 요약 문서의 핵심 용어(KeyPoint)와 설명을 생성한 내용입니다. 이 요약 문서는 유니티에서 뱀서라이크 게임을 위한 몬스터 제작 과정을 상세히 설명하고 있으며, 몬스터의 로직, 애니메이션, 물리적 특성, 그리고 다양한 기능들을 다룹니다.
#
# ### 1. 유니티 (Unity)
# - 설명: 유니티는 게임 및 시뮬레이션 개발에 널리 사용되는 엔진으로, 다양한 플랫폼에서 실행 가능한 게임을 제작할 수 있습니다.
#
# ### 2. 뱀서라이크 (Cocodile)
# - 설명: 뱀서라이크 게임은 플레이어가 자신의 캐릭터를 조종하며, 지속적으로 생성되는 적을 물리치고 생존을 추구하는 롤플레잉 요소를 포함합니다.
#
# ### 3. 에셋 (Assets)
# - 설명: 게임 개발에서 에셋은 음악, 이미지, 모델 등 게임 내에서 사용되는 요소들을 의미합니다. 에셋은 게임의 비주얼과 사운드 요소를 구축하는 중요한 역할을 합니다.
#
# ### 4. 스프라이트 (Sprite)
# - 설명: 스프라이트는 2D 게임에서 사용되는 잘라낸 이미지나 그림을 의미합니다. 캐릭터, 아이템, 이펙트 등 다양한 요소의 비주얼을 표현할 수 있습니다.
#
# ### 5. 리지드 바디 2D (2D Rigidbody)
# - 설명: 리지드 바디 2D 컴포넌트는 물리적 상호작용을 위해 오브젝트에 물리적 특성을 부여하는 기능을 제공하며, 중력이나 충돌 감지 등을 설정할 수 있습니다.
#
# ### 6. 캡슐 콜라이더 2D (Capsule Collider 2D)
# - 설명: 캡슐 콜라이더 2D는 2D 공간에서 오브젝트의 물리적 경계를 정의하는 컴포넌트로, 캐릭터의 충돌 처리를 보다 쉽게 만들어 줍니다.
#
# ### 7. 그래비티 스케일 (Gravity Scale)
# - 설명: 그래비티 스케일은 리지드 바디 컴포넌트에서 중력의 영향을 얼마나 받을지를 결정하는 값으로, 0으로 설정하면 중력이 적용되지 않도록 할 수 있습니다.
#
# ### 8. 유니티 허브 (Unity Hub)
# - 설명: 유니티 허브는 유니티 엔진의 다양한 버전을 관리하고 프로젝트를 생성할 수 있는 툴로, 버전 관리와 라이센스 관리를 돕습니다.
#
# ### 9. URP (Universal Render Pipeline)
# - 설명: URP는 유니티에서 제공하는 렌더링 파이프라인의 하나로, 다양한 플랫폼에서 최적화된 성능을 제공하면서도 시각적으로 우수한 결과를 만들어낼 수 있게끔 설계되었습니다.
#
# ### 10. 스프라이트 설정 (Sprite Settings)
# - 설명: 스프라이트 설정은 스프라이트 이미지의 해상도, 필터링 등 다양한 속성을 조정하여 게임 내 비주얼 품질을 최적화하는 과정입니다.
#
# ### 추가 핵심 용어:
# ### 11. 몬스터 스프라이트 (Monster Sprites)
# - 설명: 게임 내에서 몬스터가 나타날 때 사용되는 스프라이트 이미지로, 다양한 몬스터의 외형을 표현합니다.
#
# ### 12. 애니메이터 (Animators)
# - 설명: 애니메이터는 게임 내에서 몬스터의 애니메이션을 담당하는 컴포넌트로, 다양한 애니메이션이 적용되도록 설정할 수 있습니다.
#
# ### 13. 에너미 (Energy)
# - 설명: 에너미는 게임 내에서 몬스터의 생명력이나 능력을 나타내는 요소로, 게임 내에서 쉽게 식별할 수 있도록 태그를 추가합니다.
#
# ### 14. 리포지션 (Replication)
# - 설명: 리포지션 기능은 몬스터가 플레이어와의 거리를 유지하고, 랜덤하게 재배치되도록 설정합니다. 랜덤 레인지를 사용해 다양한 위치에서 등장하도록 합니다.
#
# ### 15. 콜라이더 2D (Collider 2D)
# - 설명: 콜라이더 2D는 2D 공간에서 오브젝트의 물리적 경계를 정의하는 컴포넌트로, 캐릭터의 충돌 처리를 보다 쉽게 만들어 줍니다.
# Inference Time: 30.61 seconds
# Peak GPU Memory Usage: 4.80 GB
# BLEU score: 0.0033
# Log probability score (sum): -81.2075
#
# ==== Example 7 ====
# Candidate output:
# ### 10개의 핵심 용어와 설명
#
# 1. **유니티 (Unity)**
#    - **설명**: 게임 및 시뮬레이션 개발에 널리 사용되는 엔진으로, 2D 및 3D 게임 제작에 필요한 다양한 툴과 기능을 제공합니다. 다양한 플랫폼에 배포할 수 있는 크로스 플랫폼 기능이 특징입니다.
#
# 2. **뱀서라이크 (Debris)**
#    - **설명**: 게임 장르로 플레이어가 자신의 캐릭터를 조종하여 지속적으로 생성되는 적을 물리치고 생존을 추구하는 게임 유형입니다. 주로 롤플레잉 요소를 포함합니다.
#
# 3. **에셋 (Assets)**
#    - **설명**: 게임 개발에서 음악, 이미지, 모델 등 게임 내에서 사용되는 요소들을 의미합니다. 에셋은 게임의 비주얼과 사운드 요소를 구축하는 중요한 역할을 합니다.
#
# 4. **스프라이트 (Sprites)**
#    - **설명**: 2D 게임에서 사용되는 잘라낸 이미지나 그림을 의미합니다. 캐릭터, 아이템, 이펙트 등 다양한 요소의 비주얼을 표현할 수 있습니다.
#
# 5. **리지드 바디 2D (Rigged Body 2D)**
#    - **설명**: 물리적 상호작용을 위해 오브젝트에 물리적 특성을 부여하는 기능을 제공하며, 중력이나 충돌 감지 등을 설정할 수 있는 컴포넌트입니다.
#
# 6. **캡슐 콜라이더 2D (Capsule Collider 2D)**
#    - **설명**: 2D 공간에서 오브젝트의 물리적 경계를 정의하는 컴포넌트로, 캐릭터의 충돌 처리를 보다 쉽게 만들어 줍니다.
#
# 7. **그래비티 스케일 (Gravity Scale)**
#    - **설명**: 리지드 바디 컴포넌트에서 중력의 영향을 얼마나 받을지를 결정하는 값으로, 0으로 설정하면 중력이 적용되지 않도록 할 수 있습니다.
#
# 8. **유니티 허브 (Unity Hub)**
#    - **설명**: 유니티 엔진의 다양한 버전을 관리하고 프로젝트를 생성할 수 있는 툴로, 버전 관리와 라이센스 관리를 돕습니다.
#
# 9. **URP (Universal Render Pipeline)**
#    - **설명**: 유니티에서 제공하는 렌더링 파이프라인의 하나로, 다양한 플랫폼에서 최적화된 성능을 제공하면서도 시각적으로 우수한 결과를 만들어낼 수 있게끔 설계되었습니다.
#
# 10. **스프라이트 설정 (Sprite Settings)**
#     - **설명**: 스프라이트 이미지의 해상도, 필터링 등 다양한 속성을 조정하여 게임 내 비주얼 품질을 최적화하는 과정입니다.
#
# 이 외에도 게임 개발과 관련된 여러 용어들이 포함되어 있습니다. 예를 들어, **프리팬 (Prefabs)**, **오브젝트 풀 (Object Pool)**, **풀 매니저 (Pool Manager)** 등도 중요한 개념입니다.
# Inference Time: 21.26 seconds
# Peak GPU Memory Usage: 4.50 GB
# BLEU score: 0.0031
# Log probability score (sum): -26.6191
#
# ==== Example 8 ====
# Candidate output:
# 1. **유니티 (Unity)**
#    - **설명**: 게임 및 시뮬레이션 개발에 널리 사용되는 엔진으로, 다양한 플랫폼에 배포할 수 있는 크로스 플랫폼 기능이 특징입니다.
#
# 2. **뱀서라이크 (Cocodile)**
#    - **설명**: 뱀서라이크 게임 장르는 플레이어가 자신의 캐릭터를 조종하여 지속적으로 생성되는 적을 물리치고 생존을 추구하는 게임 유형으로, 주로 롤플레잉 요소를 포함합니다.
#
# 3. **에셋 (Assets)**
#    - **설명**: 게임 개발에서 에셋은 음악, 이미지, 모델 등 게임 내에서 사용되는 요소들을 의미합니다. 에셋은 게임의 비주얼과 사운드 요소를 구축하는 중요한 역할을 합니다.
#
# 4. **스프라이트 (Sprite)**
#    - **설명**: 2D 게임에서 사용되는 잘라낸 이미지나 그림을 의미합니다. 캐릭터, 아이템, 이펙트 등 다양한 요소의 비주얼을 표현할 수 있습니다.
#
# 5. **리지드 바디 2D (2D Rigidbody Component)**
#    - **설명**: 물리적 상호작용을 위해 오브젝트에 물리적 특성을 부여하는 기능을 제공하며, 중력이나 충돌 감지 등을 설정할 수 있습니다.
#
# 6. **캡슐 콜라이더 2D (2D Capsule Collider Component)**
#    - **설명**: 2D 공간에서 오브젝트의 물리적 경계를 정의하는 컴포넌트로, 캐릭터의 충돌 처리를 보다 쉽게 만들어 줍니다.
#
# 7. **그래비티 스케일 (Gravity Scale)**
#    - **설명**: 리지드 바디 컴포넌트에서 중력의 영향을 얼마나 받을지를 결정하는 값으로, 0으로 설정하면 중력이 적용되지 않도록 할 수 있습니다.
#
# 8. **유니티 허브 (Unity Hub)**
#    - **설명**: 유니티 엔진의 다양한 버전을 관리하고 프로젝트를 생성할 수 있는 툴로, 버전 관리와 라이센스 관리를 돕습니다.
#
# 9. **URP (Universal Render Pipeline)**
#    - **설명**: 유니티에서 제공하는 렌더링 파이프라인의 하나로, 다양한 플랫폼에서 최적화된 성능을 제공하면서도 시각적으로 우수한 결과를 만들어낼 수 있게끔 설계되었습니다.
#
# 10. **스프라이트 설정 (Sprite Settings)**
#     - **설명**: 스프라이트 이미지의 해상도, 필터링 등 다양한 속성을 조정하여 게임 내 비주얼 품질을 최적화하는 과정입니다.
# Inference Time: 18.45 seconds
# Peak GPU Memory Usage: 4.30 GB
# BLEU score: 0.0039
# Log probability score (sum): -15.2416
#
# ==== Example 9 ====
# Candidate output:
# ```json
# [
#     {
#         'term': '유니티',
#         'description': '유니티는 게임 및 시뮬레이션 개발에 널리 사용되는 엔진으로, 2D 및 3D 게임을 제작하는 데 필요한 다양한 툴과 기능을 제공합니다. 다양한 플랫폼에 배포할 수 있는 크로스 플랫폼 기능이 특징입니다.'
#     },
#     {
#         'term': '프리펩',
#         'description': '프리펩은 게임 오브젝트의 인스턴스를 쉽게 재사용할 수 있도록 도와주는 유용한 기능입니다. 유니티에서 게임 오브젝트를 재사용하기 위해 필요한 프리펩을 생성할 수 있습니다.'
#     },
#     {
#         'term': '충돌 로직',
#         'description': '충돌 로직은 무기가 몬스터와 충돌할 때의 반응을 정의합니다. 유니티의 기준 충돌 메서드를 사용하여, 충돌 시 몬스터의 상태를 변경하는 특정 함수들을 추가하게 됩니다.'
#     },
#     {
#         'term': '무기 배치',
#         'description': '무기의 위치 조정과 방향 회전 설정을 통해 플레이어 주위에 적절한 무기를 배치합니다. 무기의 태그를 설정하여 나중에 충돌 관리에 사용될 수 있도록 합니다.'
#     },
#     {
#         'term': '회전 로직',
#         'description': '무기의 회전 로직을 구현하여 무기가 적절한 방향으로 회전하도록 설정합니다. 변수와 메서드를 적절히 활용하여 스무스한 애니메이션을 만드는 법을 배웁니다.'
#     },
#     {
#         'term': '레벨에 따른 배치 방식',
#         'description': '게임 레벨에 따라 근접무기의 배치 방식을 조정합니다. 각 레벨에 적합한 무기 배치 로직을 설정하여, 레벨의 진행에 따라 플레이어가 사용할 수 있는 무기가 달라질 수 있도록 합니다.'
#     },
#     {
#         'term': '에셋',
#         'description': '게임 개발에서 에셋은 음악, 이미지, 모델 등 게임 내에서 사용되는 요소들을 의미합니다. 에셋은 게임의 비주얼과 사운드 요소를 구축하는 중요한 역할을 합니다.'
#     },
#     {
#         'term': '스프라이트',
#         'description': '스프라이트는 2D 게임에서 사용되는 잘라낸 이미지나 그림을 의미합니다. 캐릭터, 아이템, 이펙트 등 다양한 요소의 비주얼을 표현할 수 있습니다.'
#     },
#     {
#         'term': '리지드 바디 2D',
#         'description': '리지드 바디 2D 컴포넌트는 물리적 상호작용을 위해 오브젝트에 물리적 특성을 부여하는 기능을 제공하며, 중력이나 충돌 감지 등을 설정할 수 있습니다.'
#     },
#     {
#         'term': '캡슐 콜라이더 2D',
#         'description': '캡슐 콜라이더 2D는 2D 공간에서 오브젝트의 물리적 경계를 정의하는 컴포넌트로, 캐릭터의 충돌 처리를 보다 쉽게 만들어 줍니다.'
#     },
#     {
#         'term': '그래비티 스케일',
#         'description': '그래비티 스케일은 리지드 바디 컴포넌트에서 중력의 영향을 얼마나 받을지를 결정하는 값으로, 0으로 설정하면 중력이 적용되지 않도록 할 수 있습니다.'
#     },
#     {
#         'term': '유니티 허브',
#         'description': '유니티 허브는 유니티 엔진의 다양한 버전을 관리하고 프로젝트를 생성할 수 있는 툴로, 버전 관리와 라이센스 관리를 돕습니다.'
#     },
#     {
#         'term': 'URP (Universal Render Pipeline)',
#         'description': 'URP는 유니티에서 제공하는 렌더링 파이프라인의 하나로, 다양한 플랫폼에서 최적화된 성능을 제공하면서도 시각적으로 우수한 결과를 만들어낼 수 있게끔 설계되었습니다.'
#     },
#     {
#         'term': '스프라이트 설정',
#         'description': '스프라이트 설정은 스프라이트 이미지의 해상도, 필터링 등 다양한 속성을 조정하여 게임 내 비주얼 품질을 최적화하는 과정입니다.'
#     }
# ]
# ```
# Inference Time: 29.23 seconds
# Peak GPU Memory Usage: 4.50 GB
# BLEU score: 0.0040
# Log probability score (sum): -29.9348
#
# ==== Example 10 ====
# Candidate output:
# ### 핵심 용어(KeyPoint)와 설명
#
# 1. **유니티 (Unity)**
#    - **설명**: 유니티는 게임 및 시뮬레이션 개발에 널리 사용되는 엔진으로, 2D 및 3D 게임을 제작하는 데 필요한 다양한 툴과 기능을 제공합니다. 다양한 플랫폼에 배포할 수 있는 크로스 플랫폼 기능이 특징입니다.
#
# 2. **뱀서라이크 (BunnyRabbit)**
#    - **설명**: 뱀서라이크 게임 장르는 플레이어가 자신의 캐릭터를 조종하여 지속적으로 생성되는 적을 물리치고 생존을 추구하는 게임 유형으로, 주로 롤플레잉 요소를 포함합니다.
#
# 3. **에셋 (Assets)**
#    - **설명**: 게임 개발에서 에셋은 음악, 이미지, 모델 등 게임 내에서 사용되는 요소들을 의미합니다. 에셋은 게임의 비주얼과 사운드 요소를 구축하는 중요한 역할을 합니다.
#
# 4. **스프라이트 (Sprites)**
#    - **설명**: 스프라이트는 2D 게임에서 사용되는 잘라낸 이미지나 그림을 의미합니다. 캐릭터, 아이템, 이펙트 등 다양한 요소의 비주얼을 표현할 수 있습니다.
#
# 5. **리지드 바디 2D (2D Rigidbody)**
#    - **설명**: 리지드 바디 2D 컴포넌트는 물리적 상호작용을 위해 오브젝트에 물리적 특성을 부여하는 기능을 제공하며, 중력이나 충돌 감지 등을 설정할 수 있습니다.
#
# 6. **캡슐 콜라이더 2D (2D Capsule Collider)**
#    - **설명**: 캡슐 콜라이더 2D는 2D 공간에서 오브젝트의 물리적 경계를 정의하는 컴포넌트로, 캐릭터의 충돌 처리를 보다 쉽게 만들어 줍니다.
#
# 7. **그래비티 스케일 (Gravity Scale)**
#    - **설명**: 그래비티 스케일은 리지드 바디 컴포넌트에서 중력의 영향을 얼마나 받을지를 결정하는 값으로, 0으로 설정하면 중력이 적용되지 않도록 할 수 있습니다.
#
# 8. **유니티 허브 (Unity Hub)**
#    - **설명**: 유니티 허브는 유니티 엔진의 다양한 버전을 관리하고 프로젝트를 생성할 수 있는 툴로, 버전 관리와 라이센스 관리를 돕습니다.
#
# 9. **URP (Universal Render Pipeline)**
#    - **설명**: URP는 유니티에서 제공하는 렌더링 파이프라인의 하나로, 다양한 플랫폼에서 최적화된 성능을 제공하면서도 시각적으로 우수한 결과를 만들어낼 수 있게끔 설계되었습니다.
#
# 10. **스프라이트 설정 (Sprite Settings)**
#     - **설명**: 스프라이트 설정은 스프라이트 이미지의 해상도, 필터링 등 다양한 속성을 조정하여 게임 내 비주얼 품질을 최적화하는 과정입니다.
#
# ### 추가 핵심 용어
#
# 11. **레이캐스트 히트 (Raycast Hit)**
#     - **설명**: 레이캐스트 히트는 2D 레이캐스트를 사용하여 오브젝트의 물리적 경계를 확인하는 방법으로, 충돌 감지 로직을 구현할 때 자주 사용됩니다.
#
# 12. **서클 캐스트 (Circle Cast)**
#     - **설명**: 서클 캐스트는 원형 범위 내의 모든 적을 탐색하는 방법으로, 원거리 공격 시스템에서 플레이어와 가까운 적을 찾는 데 사용됩니다.
#
# 이 문서는 유니티를 사용하여 원거리 공격 시스템을 구현하는 방법에 대한 강좌를 요약한 내용입니다. 이 과정에서 주요 용어와 설명을 통해 유니티와 관련된 다양한 게임 개발 용어들을 설명하고 있습니다.
# Inference Time: 26.29 seconds
# Peak GPU Memory Usage: 4.60 GB
# BLEU score: 0.0040
# Log probability score (sum): -45.4131
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>BLEU_score</td><td>█▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Inference_time_sec</td><td>▂▃█▇▇▇▂▁▆▅</td></tr><tr><td>Log_probability_score</td><td>█▁▅▆▃▄▇▇▇▆</td></tr><tr><td>Peak_GPU_Memory_GB</td><td>▁▅▆▇▇█▆▅▆▇</td></tr><tr><td>basic_memory</td><td>▁</td></tr><tr><td>example_index</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>BLEU_score</td><td>0.00398</td></tr><tr><td>Inference_time_sec</td><td>26.28639</td></tr><tr><td>Log_probability_score</td><td>-45.41315</td></tr><tr><td>Peak_GPU_Memory_GB</td><td>4.6</td></tr><tr><td>basic_memory</td><td>3.1</td></tr><tr><td>example_index</td><td>9</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">5B_4Bit_Quant</strong> at: <a href='https://wandb.ai/iamkimhongil92-lumenasoft/hangae_Final/runs/yvtssjaf' target="_blank">https://wandb.ai/iamkimhongil92-lumenasoft/hangae_Final/runs/yvtssjaf</a><br> View project at: <a href='https://wandb.ai/iamkimhongil92-lumenasoft/hangae_Final' target="_blank">https://wandb.ai/iamkimhongil92-lumenasoft/hangae_Final</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250213_124346-yvtssjaf/logs</code>
